# %%
# create a API key from Google cloud Console
# the Copy Paste youtube video link and keep the ID only.

api_key = "AIzaSyBkS9l8uJIgmsCDeL07eDzIrCwq_EXA5pk"
video_id=input("enter Video ID: ")
# Out:
# enter Video ID:  M3Dzu4DLhV4

# %%
# importing necessary liberaries

import time
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
# function for fetching comments and dispaying them in understandable manner

def get_video_comments(video_id, api_key, max_comments=1000):
    youtube = build('youtube', 'v3', developerKey=api_key)
    comments = []
    next_page_token = None
    fetched_comments = 0
    
    try:
        while fetched_comments < max_comments:
            response = youtube.commentThreads().list(
                part='snippet',
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
                order='relevance'
            ).execute()
            
            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comments.append(comment)
                fetched_comments += 1
                if fetched_comments >= max_comments:
                    break
            
            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break

            time.sleep(1)  # Respect rate limits

    except HttpError as e:
        print(f"An HTTP error occurred: {e}")
    
    return comments

def display_comments(comments):
    for idx, comment in enumerate(comments):
        print(f"Comment {idx + 1}: {comment}\n")

# Fetch comments
comments = get_video_comments(video_id, api_key, max_comments=500)

# %%
# Display comments
print(f"Number of comments fetched: {len(comments)}")
display_comments(comments)
# Out:
# Number of comments fetched: 500
# Comment 1: Yeah so I achieved this by accident. I was trying to get buff, not skinny strong
#
# Comment 2: This is why I hate when people discredit Bruce Lee for his size
#
# Comment 3: I swear this is what K Boges recommends us doing, no overtraining, keep your form tight and do them every day. Physical and physiological hygiene.
#
# Comment 4: This program works!<br><br>I doubled my pull ups.... from 1 rep to 2.
#
# Comment 5: This is why old school labourers/builders are lean and strong compared to beefed up gym goers
#
# Comment 6: Most people fail because the urge to overtrain is very powerful. I used to do this will pull ups everyday and got joint problems. The amount of reps or sets you should be doing will be far less than you think it should be if you&#39;re doing it everyday.
#
# Comment 7: I did this with pull-ups, after about 2 months, I could rep 20 with ease, and my back looked like Yujiro.
#
# Comment 8: It’s old man strength.
#
# ...
